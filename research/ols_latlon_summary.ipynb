# %% [markdown]
# # Check OLS fit statistics
#
# Findings: Latitude is not a statistically significant covariate for linear regression with SIF.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../src")

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs

import spatial_tools
import fields

# %%
# Get data: 5-degree monthly average, cont. US
ds = xr.open_dataset("../data/exp_pro/OCO2_4x5deg_monthly_conus.nc")

# Format as multi-fields
ds_xco2 = ds[["xco2", "xco2_var"]]
ds_sif = ds[["sif", "sif_var"]]

var_names = ["xco2", "sif"]
cross_name = "xco2:sif"

# %%
# Analysis variables
month = 8
timedelta = -2
fast_dist = True

timestamps = np.array(ds.time[ds.time.dt.month == month].values, dtype="datetime64[D]")

# %%
[fields.MultiField(ds_xco2, ds_sif, timestamp, timedelta=timedelta, fast_dist=fast_dist) for timestamp in timestamps]
# Out:
# xco2
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     123.4
# Date:                Sat, 08 May 2021   Prob (F-statistic):           1.60e-26
# Time:                        07:38:39   Log-Likelihood:                -134.23
# No. Observations:                  93   AIC:                             274.5
# Df Residuals:                      90   BIC:                             282.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3610      0.722     -3.272      0.002      -3.794      -0.928
# ...
